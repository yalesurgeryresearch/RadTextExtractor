# %%
import optuna
import os

# %%
study_path = ".db" # Replace with the path to your .db file

study_name = os.path.splitext(os.path.basename(study_path))[0]
storage_name = f'sqlite:///{study_path}'  # Replace with the path to your .db file

# Load the study
study = optuna.load_study(study_name=study_name, storage=storage_name)


# Get all completed trials and sort by value in descending order
completed_trials = [trial for trial in study.trials if trial.state == optuna.trial.TrialState.COMPLETE]
top_trials = sorted(completed_trials, key=lambda t: t.value, reverse=False)

# Print the trials in descending order
for i, trial in enumerate(top_trials, 1):
    print(f'Top {i} trial number: {trial.number}')
    print(f'  Value: {trial.value}')
    print(f'  Params: {trial.params}')
    print(f'  State: {trial.state}')
    print(f'  Duration: {trial.duration}')
    print(f'  User attrs: {trial.user_attrs}')
    print('-' * 20)
# Out:
# Top 1 trial number: 7
#   Value: 0.6814883551965246
#   Params: {'learning-Rate': 1e-05, 'batch-size': 32}
#   State: 1
#   Duration: 0:05:51.867760
#   User attrs: {'eval_result': {'eval_loss': 0.06603723019361496, 'eval_precision': 0.6827762736448162, 'eval_recall': 0.7124815940852638, 'eval_f1': 0.6814883551965246, 'eval_runtime': 2.1447, 'eval_samples_per_second': 48.026, 'eval_steps_per_second': 1.865, 'epoch': 20.0}}
# --------------------
# Top 2 trial number: 11
#   Value: 0.8450117697655332
#   Params: {'learning-Rate': 1e-05, 'batch-size': 16}
#   State: 1
#   Duration: 0:06:02.712301
#   User attrs: {'eval_result': {'eval_loss': 0.04555942863225937, 'eval_precision': 0.8335696523295694, 'eval_recall': 0.8738474218402135, 'eval_f1': 0.8450117697655332, 'eval_runtime': 2.162, 'eval_samples_per_second': 47.642, 'eval_steps_per_second': 1.85, 'epoch': 20.0}}
# --------------------
# Top 3 trial number: 1
#   Value: 0.8622576611806869
#   Params: {'learning-Rate': 2e-05, 'batch-size': 32}
#   State: 1
#   Duration: 0:05:55.890428
#   User attrs: {'eval_result': {'eval_loss': 0.041301194578409195, 'eval_precision': 0.8613394866493087, 'eval_recall': 0.8808075677708616, 'eval_f1': 0.8622576611806869, 'eval_runtime': 2.1743, 'eval_samples_per_second': 47.371, 'eval_steps_per_second': 1.84, 'epoch': 20.0}}
# --------------------
# Top 4 trial number: 2
#   Value: 0.8745798617387017
#   Params: {'learning-Rate': 1e-05, 'batch-size': 8}
#   State: 1
#   Duration: 0:06:24.871628
#   User attrs: {'eval_result': {'eval_loss': 0.045471977442502975, 'eval_precision': 0.8546416245339261, 'eval_recall': 0.9093351582211197, 'eval_f1': 0.8745798617387017, 'eval_runtime': 2.1665, 'eval_samples_per_second': 47.543, 'eval_steps_per_second': 1.846, 'epoch': 20.0}}
# --------------------
# Top 5 trial number: 9
#   Value: 0.8868029543284744
#   Params: {'learning-Rate': 2e-05, 'batch-size': 16}
#   State: 1
#   Duration: 0:06:03.750041
#   User attrs: {'eval_result': {'eval_loss': 0.03356245160102844, 'eval_precision': 0.8681140010227766, 'eval_recall': 0.9084769992852042, 'eval_f1': 0.8868029543284744, 'eval_runtime': 2.1417, 'eval_samples_per_second': 48.093, 'eval_steps_per_second': 1.868, 'epoch': 20.0}}
# --------------------
# Top 6 trial number: 3
#   Value: 0.9029525279895912
#   Params: {'learning-Rate': 5e-05, 'batch-size': 32}
#   State: 1
#   Duration: 0:05:52.389507
#   User attrs: {'eval_result': {'eval_loss': 0.03651544079184532, 'eval_precision': 0.885237969121691, 'eval_recall': 0.929317479785236, 'eval_f1': 0.9029525279895912, 'eval_runtime': 2.1747, 'eval_samples_per_second': 47.364, 'eval_steps_per_second': 1.839, 'epoch': 20.0}}
# --------------------
# Top 7 trial number: 4
#   Value: 0.9063822208244614
#   Params: {'learning-Rate': 2e-05, 'batch-size': 8}
#   State: 1
#   Duration: 0:06:23.319317
#   User attrs: {'eval_result': {'eval_loss': 0.04386701062321663, 'eval_precision': 0.8944429942760274, 'eval_recall': 0.9245032756564933, 'eval_f1': 0.9063822208244614, 'eval_runtime': 2.1823, 'eval_samples_per_second': 47.197, 'eval_steps_per_second': 1.833, 'epoch': 20.0}}
# --------------------
# Top 8 trial number: 6
#   Value: 0.912717764270583
#   Params: {'learning-Rate': 5e-05, 'batch-size': 16}
#   State: 1
#   Duration: 0:06:04.624286
#   User attrs: {'eval_result': {'eval_loss': 0.029029790312051773, 'eval_precision': 0.9086181034015595, 'eval_recall': 0.927273678419087, 'eval_f1': 0.912717764270583, 'eval_runtime': 2.1619, 'eval_samples_per_second': 47.643, 'eval_steps_per_second': 1.85, 'epoch': 20.0}}
# --------------------
# Top 9 trial number: 0
#   Value: 0.9160386063991771
#   Params: {'learning-Rate': 0.0001, 'batch-size': 32}
#   State: 1
#   Duration: 0:05:56.049706
#   User attrs: {'eval_result': {'eval_loss': 0.03590445965528488, 'eval_precision': 0.8913275215373313, 'eval_recall': 0.9461477987517607, 'eval_f1': 0.9160386063991771, 'eval_runtime': 2.1745, 'eval_samples_per_second': 47.367, 'eval_steps_per_second': 1.84, 'epoch': 20.0}}
# --------------------
# Top 10 trial number: 10
#   Value: 0.9326022826680828
#   Params: {'learning-Rate': 0.0001, 'batch-size': 8}
#   State: 1
#   Duration: 0:06:22.459548
#   User attrs: {'eval_result': {'eval_loss': 0.024669703096151352, 'eval_precision': 0.9085836804774841, 'eval_recall': 0.9588609355686144, 'eval_f1': 0.9326022826680828, 'eval_runtime': 2.1474, 'eval_samples_per_second': 47.966, 'eval_steps_per_second': 1.863, 'epoch': 20.0}}
# --------------------
# Top 11 trial number: 5
#   Value: 0.9331410082329015
#   Params: {'learning-Rate': 5e-05, 'batch-size': 8}
#   State: 1
#   Duration: 0:06:23.818485
#   User attrs: {'eval_result': {'eval_loss': 0.0320073626935482, 'eval_precision': 0.9201839367109746, 'eval_recall': 0.9470316437086963, 'eval_f1': 0.9331410082329015, 'eval_runtime': 2.1448, 'eval_samples_per_second': 48.024, 'eval_steps_per_second': 1.865, 'epoch': 20.0}}
# --------------------
# Top 12 trial number: 8
#   Value: 0.9342444627236929
#   Params: {'learning-Rate': 0.0001, 'batch-size': 16}
#   State: 1
#   Duration: 0:06:03.005001
#   User attrs: {'eval_result': {'eval_loss': 0.02858554944396019, 'eval_precision': 0.9309357228443189, 'eval_recall': 0.9433359339679518, 'eval_f1': 0.9342444627236929, 'eval_runtime': 2.161, 'eval_samples_per_second': 47.663, 'eval_steps_per_second': 1.851, 'epoch': 20.0}}
# --------------------
